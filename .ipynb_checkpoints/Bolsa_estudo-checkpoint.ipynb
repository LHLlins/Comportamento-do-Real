# %% [markdown]
# # Bibliotecas

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dados

# %%
plt.plot(preco_real_open, color = 'red', label = 'Preço abertura real')
plt.plot(preco_real_high, color = 'black', label = 'Preço alta real')

plt.plot(previsoes[:, 0], color = 'blue', label = 'Previsões abertura')
plt.plot(previsoes[:, 1], color = 'orange', label = 'Previsões alta')

plt.title('Previsão preço das ações')
plt.xlabel('Tempo')
plt.ylabel('Valor Yahoo')
plt.legend()
plt.show()

# %%
base_treinamento = base.iloc[:, 1:2].values
base_treinamento
# Out:
# array([[19.99    ],
#        [19.809999],
#        [20.33    ],
#        ...,
#        [15.99    ],
#        [16.1     ],
#        [16.1     ]])

# %%
base_valor_maximo = base.iloc[:, 2:3].values
base_valor_maximo
# Out:
# array([[20.209999],
#        [20.4     ],
#        [20.620001],
#        ...,
#        [16.139999],
#        [16.129999],
#        [16.1     ]])

# %% [markdown]
# # Processamento dos dados

# %%
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)
base_valor_maximo_normalizada = normalizador.fit_transform(base_valor_maximo)

# %% [markdown]
# # Coleta de dados

# %%
previsores = []
preco_real1 = []
preco_real2 = []
for i in range(90, 1242):
    previsores.append(base_treinamento_normalizada[i-90:i, 0])
    preco_real1.append(base_treinamento_normalizada[i, 0])
    preco_real2.append(base_valor_maximo_normalizada[i, 0])

# %%
previsores, preco_real1, preco_real2 = np.array(previsores), np.array(preco_real1), np.array(preco_real2)
previsores = np.reshape(previsores, (previsores.shape[0], previsores.shape[1], 1))

# %%
preco_real = np.column_stack((preco_real1, preco_real2))

# %% [markdown]
# # Modelo NN

# %%
regressor = Sequential()
regressor.add(LSTM(units = 100, return_sequences = True, input_shape = (previsores.shape[1], 1)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 2, activation = 'linear'))

regressor.compile(optimizer = 'rmsprop', loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
regressor.fit(previsores, preco_real, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 30s 246ms/step - loss: 0.0398 - mean_absolute_error: 0.1491
# Epoch 2/100
# 36/36 [==============================] - 9s 247ms/step - loss: 0.0178 - mean_absolute_error: 0.1045
# Epoch 3/100
# 36/36 [==============================] - 9s 249ms/step - loss: 0.0149 - mean_absolute_error: 0.0943
# Epoch 4/100
# 36/36 [==============================] - 10s 267ms/step - loss: 0.0129 - mean_absolute_error: 0.0856
# Epoch 5/100
# 36/36 [==============================] - 8s 231ms/step - loss: 0.0118 - mean_absolute_error: 0.0836
# Epoch 6/100
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0095 - mean_absolute_error: 0.0753
# Epoch 7/100
# 36/36 [==============================] - 7s 202ms/step - loss: 0.0095 - mean_absolute_error: 0.0736
# Epoch 8/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.0092 - mean_absolute_error: 0.0737
# Epoch 9/100
# 36/36 [==============================] - 8s 216ms/step - loss: 0.0074 - mean_absolute_error: 0.0652
# Epoch 10/100
# 36/36 [==============================] - 7s 201ms/step - loss: 0.0017 - mean_absolute_error: 0.0315
# Epoch 87/100
# 36/36 [==============================] - 7s 206ms/step - loss: 0.0015 - mean_absolute_error: 0.0296
# Epoch 88/100
# 36/36 [==============================] - 7s 200ms/step - loss: 0.0017 - mean_absolute_error: 0.0314
# Epoch 89/100
# 36/36 [==============================] - 9s 240ms/step - loss: 0.0016 - mean_absolute_error: 0.0296
# Epoch 90/100
# 36/36 [==============================] - 9s 240ms/step - loss: 0.0017 - mean_absolute_error: 0.0308
# Epoch 91/100
# 36/36 [==============================] - 8s 217ms/step - loss: 0.0016 - mean_absolute_error: 0.0297
# Epoch 92/100
# 36/36 [==============================] - 8s 226ms/step - loss: 0.0015 - mean_absolute_error: 0.0295
# Epoch 93/100
# 36/36 [==============================] - 8s 222ms/step - loss: 0.0015 - mean_absolute_error: 0.0282
# Epoch 94/100
# 36/36 [==============================] - 8s 225ms/step - loss: 0.0016 - mean_absolute_error: 0.0296
# Epoch 95/100
# 36/36 [==============================] - 9s 244ms/step - loss: 0.0016 - mean_absolute_error: 0.0298
# Epoch 96/100
# 36/36 [==============================] - 9s 245ms/step - loss: 0.0013 - mean_absolute_error: 0.0273
# Epoch 97/100
# 36/36 [==============================] - 8s 215ms/step - loss: 0.0016 - mean_absolute_error: 0.0299
# Epoch 98/100
# 36/36 [==============================] - 7s 194ms/step - loss: 0.0014 - mean_absolute_error: 0.0279
# Epoch 99/100
# 36/36 [==============================] - 8s 215ms/step - loss: 0.0018 - mean_absolute_error: 0.0313
# Epoch 100/100
# 36/36 [==============================] - 8s 218ms/step - loss: 0.0015 - mean_absolute_error: 0.0288

# %% [markdown]
# # Dados de Testes

# %%
base_teste = pd.read_csv('petr4_teste.csv')
preco_real_open = base_teste.iloc[:, 1:2].values
preco_real_high = base_teste.iloc[:, 2:3].values

# %%
base_completa = pd.concat((base['Open'], base_teste['Open']), axis = 0)
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = entradas.reshape(-1, 1)
entradas = normalizador.transform(entradas)

# %%
X_teste = []
for i in range(90, 112):
    X_teste.append(entradas[i-90:i, 0])
X_teste = np.array(X_teste)
X_teste = np.reshape(X_teste, (X_teste.shape[0], X_teste.shape[1], 1))

# %%
previsoes = regressor.predict(X_teste)
previsoes = normalizador.inverse_transform(previsoes)

# %% [markdown]
# # Graficar

# %%
plt.plot(preco_real_open, color = 'red', label = 'Preço abertura real')
plt.plot(preco_real_high, color = 'black', label = 'Preço alta real')

plt.plot(previsoes[:, 0], color = 'blue', label = 'Previsões abertura')
plt.plot(previsoes[:, 1], color = 'orange', label = 'Previsões alta')

plt.title('Previsão preço das ações')
plt.xlabel('Tempo')
plt.ylabel('Valor Yahoo')
plt.legend()
plt.show()
